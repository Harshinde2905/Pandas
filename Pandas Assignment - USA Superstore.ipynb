# %% [raw]
# #Task 2 - Superstore_USA
# 1 . load this data in sql and in pandas with a relation in sql
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3 . Find out how return that we ahve recived and with a product id
# 4 . try  to join order and return data both in sql and pandas
# 5 . Try to find out how many unique customer that we have
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11 . Gorup by region and find out which region is more profitable
# 12 . Try to find out overalll in which country we are giving more didscount
# 13 . Give me a list of unique postal code
# 14 . which customer segement is more profitalble find it out .
# 15 . try to find out the 10th most loss making product catagory .
# 16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd
import csvkit
import MySQLdb
import datetime

# %%
usa = pd.read_csv(r"C:\Users\harsh\Downloads\Superstore_USA.csv")

# %%
usa_return = pd.read_csv(r"C:\Users\harsh\Downloads\Superstore_USA_Returns.csv")

# %%
usa_managers = pd.read_csv(r"C:\Users\harsh\Downloads\Superstore_USA_user.csv")

# %%
usa.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code  Order Date   Ship Date  \
# ...

# %%
# !csvsql --db mysql://root:1234@127.0.0.1:3306/superstore --insert Superstore_USA.csv
# Out:
# c:\users\harsh\anaconda3\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# c:\users\harsh\anaconda3\lib\site-packages\agate\table\from_csv.py:70: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# OperationalError: (MySQLdb.OperationalError) (1050, "Table 'superstore_usa' already exists")
# [SQL:
# CREATE TABLE `Superstore_USA` (
# 	`Row ID` DECIMAL(38, 0) NOT NULL,
# 	`Order Priority` VARCHAR(13) NOT NULL,
# 	`Discount` DECIMAL(38, 2) NOT NULL,
# 	`Unit Price` DECIMAL(38, 2) NOT NULL,
# 	`Shipping Cost` DECIMAL(38, 2) NOT NULL,
# 	`Customer ID` DECIMAL(38, 0) NOT NULL,
# 	`Customer Name` VARCHAR(28) NOT NULL,
# 	`Ship Mode` VARCHAR(14) NOT NULL,
# 	`Customer Segment` VARCHAR(14) NOT NULL,
# 	`Product Category` VARCHAR(15) NOT NULL,
# 	`Product Sub-Category` VARCHAR(30) NOT NULL,
# 	`Product Container` VARCHAR(10) NOT NULL,
# ...

# %%
#q3 . Find out how return that we ahve recived and with a product id

# %%
d1 = pd.DataFrame(usa[['Order ID','Product Name']])
d2 = pd.DataFrame(usa_return['Order ID'])
return_data = pd.merge(d1,d2,how = 'right')
return_data
# Out:
#       Order ID Product Name
# 0           65          NaN
# 1          612   Xerox 1928
# 2          612         6190
# 3          614          NaN
# 4          678          NaN
# ...        ...          ...
# 1666    182681          NaN
# 1667    182683          NaN
# 1668    182750          NaN
# 1669    182781          NaN
# 1670    182906          NaN
#
# [1671 rows x 2 columns]

# %%
#q4 . try to join order and return data.

# %%
#solved same as q3
d_2 = pd.DataFrame(usa_return[['Order ID','Status']])
return_data = pd.merge(d1,d_2,how = 'right')
return_data
# Out:
#       Order ID Product Name    Status
# 0           65          NaN  Returned
# 1          612   Xerox 1928  Returned
# 2          612         6190  Returned
# 3          614          NaN  Returned
# 4          678          NaN  Returned
# ...        ...          ...       ...
# 1666    182681          NaN  Returned
# 1667    182683          NaN  Returned
# 1668    182750          NaN  Returned
# 1669    182781          NaN  Returned
# 1670    182906          NaN  Returned
#
# [1671 rows x 3 columns]

# %%
# 5) try to find number of unique customers.

# %%
usa['Customer Name'].to_frame().nunique()
# Out:
# Customer Name    2703
# dtype: int64

# %%
pd.DataFrame(usa['Customer Name'].unique())
# Out:
#                     0
# 0     Janice Fletcher
# 1       Bonnie Potter
# 2      Ronnie Proctor
# 3        Dwight Hwang
# 4           Leon Gill
# ...               ...
# 2698    Marc McDaniel
# 2699      Marvin Reid
# 2700    Florence Gold
# 2701   Frederick Cole
# 2702    Tammy Buckley
#
# [2703 rows x 1 columns]

# %%
#6) try to find region in which product is available and who is the manager.

# %%
reg = pd.DataFrame(usa[['Region','Product Name','State or Province','City','Postal Code']])
mang = pd.DataFrame(usa_managers[['Region','Manager']])
pd.merge(reg,mang,how = 'left')
# Out:
#        Region                                       Product Name  \
# 0     Central                                           Avery 49
# 1        West     SANFORD Liquid Accent™ Tank-Style Highlighters
# 2        West                                         Xerox 1968
# 3        West           Acme® Preferred Stainless Steel Scissors
# 4        West                                                V70
# ...       ...                                                ...
# 9421     East      Jet-Pak Recycled Peel 'N' Seal Padded Mailers
# 9422     East       Eldon Spacemaker® Box, Quick-Snap Lid, Clear
# 9423     East  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 9424     West  Tenex 46" x 60" Computer Anti-Static Chairmat,...
# 9425     West                      Staples #10 Colored Envelopes
#
#      State or Province        City  Postal Code  Manager
# 0             Illinois     Addison        60101    Chris
# 1           Washington   Anacortes        98221  William
# ...

# %%
# 7) find out different shipment mode and the respective percentages.

# %%
ship = usa['Ship Mode'].to_frame(name='mode')
ship['mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
pd.DataFrame(usa['Ship Mode']).nunique()
# Out:
# Ship Mode    3
# dtype: int64

# %%
mode1 = (len(ship[ship['mode'] == 'Regular Air']) / len(ship) ) * 100

# %%
mode2 = (len(ship[ship['mode'] == 'Express Air']) / len(ship) ) * 100

# %%
mode3 = (len(ship[ship['mode'] == 'Delivery Truck']) / len(ship) ) * 100

# %%
modes = {
    'Mode' : ['Regular Air','Express Air','Delivery Truck'],
    'Percentage' : [mode1,mode2,mode3]
}

# %%
modes = pd.DataFrame(modes)

# %%
# 8) Create a new column and try to find out difference between order date and shipment date

# %%
usa['Conv_OrderDate'] = pd.to_datetime(usa['Order Date'])
usa['Conv_ShipDate'] = pd.to_datetime(usa['Ship Date'])

#usa['date'] = pd.to_datetime(usa['Ship Date'], format='%d-%m-%y')

# %%
usa['Shipment Duration'] = usa['Conv_ShipDate'] - usa['Conv_OrderDate']

# %%
# 9) for que 8 find out where duration is more than 10 days.

# %%
# we have to first convert conv_date column into str format and then strip the 'days' then convert back to int to use the int data to calculate

usa['Shipment Days'] = usa['Shipment Duration'].astype(str)
#usa['Shipment Days'] = usa['Shipment Duration1'].str.replace('days', '')
usa['Shipment Days'] = usa['Shipment Duration1'].astype(int)

# %%
# shipping duration more than 10 days
mid_ship = usa[usa['Shipment Days']>10]
mid_ship
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 16     22241       Critical      0.06       15.57           1.39           10
# 24     18181       Critical      0.00        4.42           4.99           15
# ...      ...            ...       ...         ...            ...          ...
# 9405   21952  Not Specified      0.05       10.91           2.99         3397
# 9406   22599       Critical      0.01      177.98           0.99         3398
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9419   24912         Medium      0.05       35.99           1.25         3400
# 9424   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
#usa.drop('Shipment Duration1',axis=1,inplace=True)

# %%
# 10) find returned shipments for which number of days >15

# %%
returned_ship = pd.merge(usa,usa_return,how='inner',on = 'Order ID')

# %%
returns_shipment_days = returned_ship[returned_ship['Shipment Days']>15]
returns_shipment_days
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 8     5257            Low      0.09      550.98          64.59          349
# 9     6643       Critical      0.02        5.98           5.46          349
# 10     979         Medium      0.01      280.98          57.00          478
# 11     980         Medium      0.03        6.48           5.94          478
# 28    7966           High      0.05        7.99           5.03         1060
# 31    3435       Critical      0.03        5.34           5.63         1106
# 43    5883            Low      0.00        9.98          12.52         1228
# 51    5252       Critical      0.08       26.64           5.30         1314
# 52    5253       Critical      0.00        9.99           4.78         1314
# ...

# %%
# 11) group by region and find out the most profitable region.

# %%
profitable_region = usa.groupby('Region')['Profit'].sum()
profitable_region = profitable_region.to_frame(name='Profit')

# %%
profitable_region = profitable_region.sort_values(by='Profit',ascending=False)

# %%
profitable_region
# Out:
#                 Profit
# Region
# Central  519825.567066
# East     377566.186045
# West     310849.453891
# South    104201.192421

# %%
profitable_region[profitable_region["Profit"] == max(profitable_region["Profit"])]
# Out:
#                 Profit
# Region
# Central  519825.567066

# %%
# 12)  try to find overall in which country/region more discount is offered.

# %%
max_discount_country = usa.groupby('State or Province')['Discount'].sum()
max_discount_country = max_discount_country.to_frame(name='TotalDiscount').sort_values(by='TotalDiscount',ascending=False)

# %%
max_discount_country[max_discount_country['TotalDiscount'] == max(max_discount_country['TotalDiscount'])]
# Out:
#                    TotalDiscount
# State or Province
# California                 52.28

# %%
max_discount_region = usa.groupby('Region')['Discount'].sum()
max_discount_region = max_discount_region.to_frame(name='TotalDiscount').sort_values(by='TotalDiscount',ascending= False)

# %%
max_discount_region
# Out:
#          TotalDiscount
# Region
# Central         143.06
# East            114.45
# West            113.75
# South            96.53

# %%
max_discount_region[max_discount_region['TotalDiscount'] == max(max_discount_region['TotalDiscount'])]
# Out:
#          TotalDiscount
# Region
# Central         143.06

# %%
# 13)  list of unique postal codes

# %%
postal_codes = usa['Postal Code'].unique()

# %%
# List of Postal Codes
postal_codes.tolist()
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %%
# 14) which customer segment is more profitable.

# %%
profitable_category = usa.groupby('Product Category')['Profit'].sum()
profitable_category = profitable_category.to_frame(name='profit').sort_values(by='profit',ascending= False)
profitable_category
# Out:
#                          profit
# Product Category
# Technology        683097.884742
# Office Supplies   451990.216493
# Furniture         177354.298188

# %%
profitable_category[profitable_category['profit'] == max(profitable_category['profit'])]
# Out:
#                          profit
# Product Category
# Technology        683097.884742

# %%
# now lets see which sub category in technology has the highest profit

# %%
# customer segment

# %%
profitable_segment = usa.groupby('Customer Segment')['Profit'].sum()
profitable_segment = profitable_segment.to_frame('Profit')

# %%
profitable_segment
# Out:
#                          Profit
# Customer Segment
# Consumer          206559.625349
# Corporate         505538.627783
# Home Office       283869.553809
# Small Business    316474.592482

# %%
profitable_segment[profitable_segment['Profit'] == max(profitable_segment['Profit'])]
# Out:
#                          Profit
# Customer Segment
# Corporate         505538.627783

# %%
# 15) find 10th most loss making product category.

# %%
loss_product_category = usa.groupby('Product Sub-Category')['Profit'].sum()
loss_product_category = loss_product_category.to_frame(name = 'loss').sort_values(by = 'loss')

# %%
loss_product_category[loss_product_category['loss'] == min(loss_product_category['loss'])]
# Out:
#                               loss
# Product Sub-Category
# Tables               -72495.061875

# %%
# 16) Find out the product with highest margins.

# %%
margins = usa.groupby('Product Name')['Product Base Margin'].sum()
margins = margins.to_frame(name='margin').sort_values(by='margin',ascending=False)

# %%
margins[margins['margin'] == max(margins['margin'])]
# Out:
#                                            margin
# Product Name
# Global High-Back Leather Tilter, Burgundy   19.98
